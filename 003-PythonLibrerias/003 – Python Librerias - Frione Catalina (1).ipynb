# %% [markdown]
# # TP03 – Python Librerías

# %% [markdown]
# Frione Catalina

# %% [markdown]
# ## Ejercicio 1 – Importación de librerías

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

datos = np.array([10, 15, 20, 25, 30])

print(datos)
# Out:
# [10 15 20 25 30]

# %% [markdown]
# ## Ejercicio 2 – Dataset simple con Pandas

# %%
import pandas as pd

datos = {
    "estudiante": ["Ana", "Juan", "Carla", "Pedro", "Lucia"],
    "nota": [8, 6, 9, 5, 7]
}

df = pd.DataFrame(datos)

print(df)
print("Promedio:", df["nota"].mean())
print("Nota máxima:", df["nota"].max())
print("Nota mínima:", df["nota"].min())
# Out:
#   estudiante  nota
# 0        Ana     8
# 1       Juan     6
# 2      Carla     9
# 3      Pedro     5
# 4      Lucia     7
# Promedio: 7.0
# Nota máxima: 9
# Nota mínima: 5

# %% [markdown]
# ## Ejercicio 3 – Criterio de selección de herramientas

# %% [markdown]
# 1\.Leer un archivo CSV con datos de encuestas → Pandas: permite leer archivos CSV y trabajar con datos\. 2\. Crear un gráfico de distribución de datos → Seaborn: permite crear gráficos y visualizar datos\. 3\. Realizar un modelo de Machine Learning → Scikit\-learn: permite crear y entrenar modelos de Machine Learning\. 4\. Trabajar con operaciones matemáticas sobre matrices → NumPy: permite trabajar con matrices y realizar operaciones matemáticas\.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=980f6e57-d4ce-43e1-b370-e4ec890e8e10' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
